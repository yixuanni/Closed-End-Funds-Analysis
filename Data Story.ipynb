# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import datetime
import seaborn as sns

# %%
data = pd.read_csv('Final_Clean.csv')
data
# Out:
#       symbol        date  close.mkt  volume  adjusted.mkt  close.nav
# 0        AFB    2019/1/2      12.37   80900     10.031555      14.26  \
# 1        AFB    2019/1/3      12.33   50300     10.036439      14.28
# 2        AFB    2019/1/4      12.32   68400     10.028296      14.27
# 3        AFB    2019/1/7      12.48  105200     10.158534      14.27
# 4        AFB    2019/1/8      12.45   68200     10.134113      14.25
# ...      ...         ...        ...     ...           ...        ...
# 69006    VMO  2023/10/30       8.01  296400      8.010000       9.47
# 69007    VMO  2023/10/31       8.06  208800      8.060000       9.49
# 69008    VMO   2023/11/1       8.23  341900      8.230000       9.52
# 69009    VMO   2023/11/2       8.37  181800      8.370000       9.72
# 69010    VMO   2023/11/3       8.49  215800      8.490000       9.72
#
#        adjusted.nav       prem Class  ExpenseRatio
# 0         12.446114 -13.253859   GML        0.0178  \
# ...

# %%
tickers = sorted(list(set(data.symbol)))
len(tickers)
# tickers
# Out:
# 57

# %%
column_names = list(data.columns)
column_names
# Out:
# ['symbol',
#  'date',
#  'close.mkt',
#  'volume',
#  'adjusted.mkt',
#  'close.nav',
#  'adjusted.nav',
#  'prem',
#  'Class',
#  'ExpenseRatio',
#  'Name',
#  'Inception date',
#  'Category1',
#  'Category2',
#  'Category3',
#  'Market cap',
#  'Current dividend yield',
#  'Historical average dividend yield',
#  'Leverage factor',
#  'Average volume']

# %%
# split the data into train_set and test_set
data['date'] = pd.to_datetime(data['date'])
train_set = data[data['date'].dt.year <= 2021]  # use 3 years' data to train and 2 years' data to test
test_set = data[data['date'].dt.year > 2021]
test_set
# Out:
#       symbol       date  close.mkt  volume  adjusted.mkt  close.nav
# 757      AFB 2022-01-03      14.90   41400     13.743543      15.34  \
# 758      AFB 2022-01-04      14.76   57800     13.614411      15.32
# 759      AFB 2022-01-05      14.77   76600     13.623634      15.28
# 760      AFB 2022-01-06      14.66   62200     13.570868      15.17
# 761      AFB 2022-01-07      14.69   50900     13.598639      15.15
# ...      ...        ...        ...     ...           ...        ...
# 69006    VMO 2023-10-30       8.01  296400      8.010000       9.47
# 69007    VMO 2023-10-31       8.06  208800      8.060000       9.49
# 69008    VMO 2023-11-01       8.23  341900      8.230000       9.52
# 69009    VMO 2023-11-02       8.37  181800      8.370000       9.72
# 69010    VMO 2023-11-03       8.49  215800      8.490000       9.72
#
#        adjusted.nav       prem Class  ExpenseRatio
# 757       15.021513  -2.868322   GML        0.0178  \
# ...

# %%
train_set.to_csv('cef_train.csv', index=False)
test_set.to_csv('cef_test.csv', index=False)
